# %% [markdown]
# **Recuerde no agregar o quitar celdas en este notebook, ni modificar su tipo. Si lo hace, el sistema automaticamente lo calificará con cero punto cero (0.0)**

# %% [markdown]
# Ordene el archivo por letra y valor (3ra columna).

# %%
# %%writefile input.txt
# B   1999-08-28   14
# E   1999-12-06   12
# E   1993-07-21   9
# C   1991-02-12   13
# E   1995-04-25   2
# A   1992-08-22   14
# B   1999-06-11   121
# E   1993-01-27   9
# E   1999-09-10   11
# E   1990-05-03   16
# E   1994-02-14   10
# A   1988-04-27   121
# A   1990-10-06   10
# E   1985-02-12   16
# E   1998-09-14   2
# B   1994-08-30   17
# A   1997-12-15   13
# B   1995-08-23   1
# B   1998-11-22   131
# B   1997-04-09   14
# E   1993-12-27   18
# E   1999-01-14   15
# A   1992-09-19   8
# B   1993-03-02   14
# B   1999-10-21   13
# A   1990-08-31   12
# C   1994-01-25   10
# E   1990-02-09   18
# A   1990-09-26   8
# A   1993-05-08   16
# B   1995-09-06   14
# E   1991-02-18   141
# A   1993-01-11   14
# A   1990-07-22   0
# C   1994-09-09   15
# C   1994-07-27   104
# D   1990-10-10   15
# A   1990-09-05   11
# B   1991-10-01   9
# A   1994-10-25   13
# Out:
# Writing input.txt

# %% [markdown]
# ## Mapper

# %%
# %%writefile mapper.py
#! /usr/bin/env python

import sys
if __name__ == "__main__": 
    for line in sys.stdin:
        splitLine = line.split()
        sys.stdout.write( "{}\t{}\t{}\n".format( splitLine[0], splitLine[1], splitLine[2] ) )
# Out:
# Overwriting mapper.py

# %% [markdown]
# ## Reducer

# %%
# %%writefile reducer.py
#!/usr/bin/env python

import sys
from operator import itemgetter
if __name__ == '__main__':
    
    tuplesList = []
    
    for line in sys.stdin:
        tuplesList.append( tuple( line.strip().split("\t") ) )
    # La lista de tuplas se ordenará por la columna 0 (las letras) y la columna 2 de enteros (los números)
    # con una función lambda
    sortedList = sorted( tuplesList, key=lambda row: (row[0], int(row[2])) )
    for tupleItem in sortedList:
        sys.stdout.write( "{}   {}   {}\n".format(tupleItem[0], tupleItem[1], tupleItem[2]) )
# Out:
# Overwriting reducer.py

# %% [markdown]
# ## Ejecución

# %%
# %%bash
# rm -rf output
# STREAM=$HADOOP_HOME/share/hadoop/tools/lib/hadoop-streaming-*.jar
# chmod +x mapper.py
# chmod +x reducer.py
# $HADOOP_HOME/bin/hadoop jar $STREAM -input input.txt -output output  -mapper mapper.py -reducer reducer.py
# cat output/part-00000
# Out:
# A   1990-07-22   4
# A   1990-09-26   5
# A   1988-04-27   9
# A   1990-10-06   10
# A   1990-09-05   11
# A   1990-08-31   12
# A   1994-10-25   13
# A   1997-12-15   13
# A   1992-08-22   14
# A   1993-05-08   16
# A   1992-09-19   18
# A   1993-01-11   141
# B   1997-04-09   6
# B   1999-06-11   12
# B   1998-11-22   13
# B   1993-03-02   14
# B   1999-08-28   14
# B   1994-08-30   17
# B   1995-08-23   101
# B   1999-10-21   131
# B   1995-09-06   141
# B   1991-10-01   151
# C   1994-07-27   1
# C   1991-02-12   2
# C   1994-01-25   10
# C   1994-09-09   151
# D   1990-10-10   151
# E   1998-09-14   7
# E   1993-01-27   8
# E   1999-09-10   11
# E   1991-02-18   14
# E   1999-01-14   15
# E   1985-02-12   16
# E   1990-05-03   16
# E   1993-07-21   17
# E   1990-02-09   18
# E   1994-02-14   101
# E   1999-12-06   121
# E   1995-04-25   161
# E   1993-12-27   181
# Java HotSpot(TM) Server VM warning: You have loaded library /home/cespedesz07/hadoop-3.1.1/lib/native/libhadoop.so.1.0.0 which might have disabled stack guard. The VM will try to fix the stack guard now.
# It's highly recommended that you fix the library with 'execstack -c <libfile>', or link it with '-z noexecstack'.
# 2018-11-19 02:03:48,130 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 2018-11-19 02:03:49,279 INFO impl.MetricsConfig: loaded properties from hadoop-metrics2.properties
# 2018-11-19 02:03:49,425 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2018-11-19 02:03:49,425 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2018-11-19 02:03:49,465 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2018-11-19 02:03:50,325 INFO mapred.FileInputFormat: Total input files to process : 1
# 2018-11-19 02:03:50,385 INFO mapreduce.JobSubmitter: number of splits:1
# 2018-11-19 02:03:50,717 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local1064359691_0001
# 2018-11-19 02:03:50,721 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2018-11-19 02:03:51,128 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 2018-11-19 02:03:51,132 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 2018-11-19 02:03:51,133 INFO mapreduce.Job: Running job: job_local1064359691_0001
# 2018-11-19 02:03:51,137 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapred.FileOutputCommitter
# 2018-11-19 02:03:51,165 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2018-11-19 02:03:51,165 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2018-11-19 02:03:51,275 INFO mapred.LocalJobRunner: Waiting for map tasks
# 2018-11-19 02:03:51,285 INFO mapred.LocalJobRunner: Starting task: attempt_local1064359691_0001_m_000000_0
# 2018-11-19 02:03:51,358 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2018-11-19 02:03:51,360 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2018-11-19 02:03:51,401 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2018-11-19 02:03:51,423 INFO mapred.MapTask: Processing split: file:/home/cespedesz07/Documents/Projects/mod-0-hadoop-cespedesz07/input.txt:0+802
# 2018-11-19 02:03:51,451 INFO mapred.MapTask: numReduceTasks: 1
# 2018-11-19 02:03:51,568 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2018-11-19 02:03:51,568 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2018-11-19 02:03:51,568 INFO mapred.MapTask: soft limit at 83886080
# 2018-11-19 02:03:51,569 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2018-11-19 02:03:51,569 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2018-11-19 02:03:51,574 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2018-11-19 02:03:51,585 INFO streaming.PipeMapRed: PipeMapRed exec [/home/cespedesz07/Documents/Projects/mod-0-hadoop-cespedesz07/./mapper.py]
# 2018-11-19 02:03:51,599 INFO Configuration.deprecation: mapred.work.output.dir is deprecated. Instead, use mapreduce.task.output.dir
# 2018-11-19 02:03:51,600 INFO Configuration.deprecation: map.input.start is deprecated. Instead, use mapreduce.map.input.start
# 2018-11-19 02:03:51,601 INFO Configuration.deprecation: mapred.task.is.map is deprecated. Instead, use mapreduce.task.ismap
# 2018-11-19 02:03:51,602 INFO Configuration.deprecation: mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2018-11-19 02:03:51,604 INFO Configuration.deprecation: mapred.tip.id is deprecated. Instead, use mapreduce.task.id
# 2018-11-19 02:03:51,604 INFO Configuration.deprecation: mapred.local.dir is deprecated. Instead, use mapreduce.cluster.local.dir
# 2018-11-19 02:03:51,604 INFO Configuration.deprecation: map.input.file is deprecated. Instead, use mapreduce.map.input.file
# 2018-11-19 02:03:51,605 INFO Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 2018-11-19 02:03:51,605 INFO Configuration.deprecation: map.input.length is deprecated. Instead, use mapreduce.map.input.length
# 2018-11-19 02:03:51,606 INFO Configuration.deprecation: mapred.job.id is deprecated. Instead, use mapreduce.job.id
# 2018-11-19 02:03:51,607 INFO Configuration.deprecation: user.name is deprecated. Instead, use mapreduce.job.user.name
# 2018-11-19 02:03:51,607 INFO Configuration.deprecation: mapred.task.partition is deprecated. Instead, use mapreduce.task.partition
# 2018-11-19 02:03:51,648 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2018-11-19 02:03:51,650 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2018-11-19 02:03:51,702 INFO streaming.PipeMapRed: Records R/W=40/1
# 2018-11-19 02:03:51,706 INFO streaming.PipeMapRed: MRErrorThread done
# 2018-11-19 02:03:51,707 INFO streaming.PipeMapRed: mapRedFinished
# 2018-11-19 02:03:51,713 INFO mapred.LocalJobRunner:
# 2018-11-19 02:03:51,713 INFO mapred.MapTask: Starting flush of map output
# 2018-11-19 02:03:51,713 INFO mapred.MapTask: Spilling map output
# 2018-11-19 02:03:51,713 INFO mapred.MapTask: bufstart = 0; bufend = 643; bufvoid = 104857600
# 2018-11-19 02:03:51,713 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26214240(104856960); length = 157/6553600
# 2018-11-19 02:03:51,743 INFO mapred.MapTask: Finished spill 0
# 2018-11-19 02:03:51,779 INFO mapred.Task: Task:attempt_local1064359691_0001_m_000000_0 is done. And is in the process of committing
# 2018-11-19 02:03:51,785 INFO mapred.LocalJobRunner: Records R/W=40/1
# 2018-11-19 02:03:51,785 INFO mapred.Task: Task 'attempt_local1064359691_0001_m_000000_0' done.
# 2018-11-19 02:03:51,808 INFO mapred.Task: Final Counters for attempt_local1064359691_0001_m_000000_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=177297
# 		FILE: Number of bytes written=685312
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=40
# 		Map output records=40
# 		Map output bytes=643
# 		Map output materialized bytes=729
# 		Input split bytes=128
# 		Combine input records=0
# 		Spilled Records=40
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=214433792
# 	File Input Format Counters
# 		Bytes Read=802
# 2018-11-19 02:03:51,809 INFO mapred.LocalJobRunner: Finishing task: attempt_local1064359691_0001_m_000000_0
# 2018-11-19 02:03:51,811 INFO mapred.LocalJobRunner: map task executor complete.
# 2018-11-19 02:03:51,817 INFO mapred.LocalJobRunner: Waiting for reduce tasks
# 2018-11-19 02:03:51,818 INFO mapred.LocalJobRunner: Starting task: attempt_local1064359691_0001_r_000000_0
# 2018-11-19 02:03:51,833 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2018-11-19 02:03:51,834 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2018-11-19 02:03:51,835 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2018-11-19 02:03:51,842 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@15b20b6
# 2018-11-19 02:03:51,847 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2018-11-19 02:03:51,885 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=605552640, maxSingleShuffleLimit=151388160, mergeThreshold=399664768, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2018-11-19 02:03:51,891 INFO reduce.EventFetcher: attempt_local1064359691_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2018-11-19 02:03:51,950 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1064359691_0001_m_000000_0 decomp: 725 len: 729 to MEMORY
# 2018-11-19 02:03:51,955 INFO reduce.InMemoryMapOutput: Read 725 bytes from map-output for attempt_local1064359691_0001_m_000000_0
# 2018-11-19 02:03:51,958 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 725, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->725
# 2018-11-19 02:03:51,961 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 2018-11-19 02:03:51,962 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2018-11-19 02:03:51,963 INFO reduce.MergeManagerImpl: finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 2018-11-19 02:03:51,984 INFO mapred.Merger: Merging 1 sorted segments
# 2018-11-19 02:03:51,985 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 721 bytes
# 2018-11-19 02:03:51,995 INFO reduce.MergeManagerImpl: Merged 1 segments, 725 bytes to disk to satisfy reduce memory limit
# 2018-11-19 02:03:51,996 INFO reduce.MergeManagerImpl: Merging 1 files, 729 bytes from disk
# 2018-11-19 02:03:51,998 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 2018-11-19 02:03:51,998 INFO mapred.Merger: Merging 1 sorted segments
# 2018-11-19 02:03:51,999 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 721 bytes
# 2018-11-19 02:03:52,000 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2018-11-19 02:03:52,009 INFO streaming.PipeMapRed: PipeMapRed exec [/home/cespedesz07/Documents/Projects/mod-0-hadoop-cespedesz07/./reducer.py]
# 2018-11-19 02:03:52,015 INFO Configuration.deprecation: mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2018-11-19 02:03:52,017 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 2018-11-19 02:03:52,075 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2018-11-19 02:03:52,076 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2018-11-19 02:03:52,115 INFO streaming.PipeMapRed: Records R/W=40/1
# 2018-11-19 02:03:52,121 INFO streaming.PipeMapRed: MRErrorThread done
# 2018-11-19 02:03:52,122 INFO streaming.PipeMapRed: mapRedFinished
# 2018-11-19 02:03:52,123 INFO mapred.Task: Task:attempt_local1064359691_0001_r_000000_0 is done. And is in the process of committing
# 2018-11-19 02:03:52,125 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2018-11-19 02:03:52,126 INFO mapred.Task: Task attempt_local1064359691_0001_r_000000_0 is allowed to commit now
# 2018-11-19 02:03:52,130 INFO output.FileOutputCommitter: Saved output of task 'attempt_local1064359691_0001_r_000000_0' to file:/home/cespedesz07/Documents/Projects/mod-0-hadoop-cespedesz07/output
# 2018-11-19 02:03:52,132 INFO mapred.LocalJobRunner: Records R/W=40/1 > reduce
# 2018-11-19 02:03:52,133 INFO mapred.Task: Task 'attempt_local1064359691_0001_r_000000_0' done.
# 2018-11-19 02:03:52,134 INFO mapred.Task: Final Counters for attempt_local1064359691_0001_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=178787
# 		FILE: Number of bytes written=686900
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=5
# 		Reduce shuffle bytes=729
# 		Reduce input records=40
# 		Reduce output records=40
# 		Spilled Records=40
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=20
# 		Total committed heap usage (bytes)=214433792
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=859
# 2018-11-19 02:03:52,134 INFO mapred.LocalJobRunner: Finishing task: attempt_local1064359691_0001_r_000000_0
# 2018-11-19 02:03:52,135 INFO mapred.LocalJobRunner: reduce task executor complete.
# 2018-11-19 02:03:52,145 INFO mapreduce.Job: Job job_local1064359691_0001 running in uber mode : false
# 2018-11-19 02:03:52,147 INFO mapreduce.Job:  map 100% reduce 100%
# 2018-11-19 02:03:53,151 INFO mapreduce.Job: Job job_local1064359691_0001 completed successfully
# 2018-11-19 02:03:53,169 INFO mapreduce.Job: Counters: 30
# 	File System Counters
# 		FILE: Number of bytes read=356084
# 		FILE: Number of bytes written=1372212
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=40
# 		Map output records=40
# 		Map output bytes=643
# 		Map output materialized bytes=729
# 		Input split bytes=128
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=5
# 		Reduce shuffle bytes=729
# 		Reduce input records=40
# 		Reduce output records=40
# 		Spilled Records=80
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=20
# 		Total committed heap usage (bytes)=428867584
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=802
# 	File Output Format Counters
# 		Bytes Written=859
# 2018-11-19 02:03:53,170 INFO streaming.StreamJob: Output directory: output

# %%
# !rm -rf mapper.py reducer.py output input.txt

# %% [markdown]
# ---

# %% [markdown]
# Para realizar la evaluación automática de este libro:
#
# * Abra un Terminal.
# * Asegurece que esat en la misma carpeta que contiene este notebook.
# * Salve el notebook.
# * Ejecute el siguiente comando:
#
#       ./gradetool 08-Taller.ipynb

# %% [markdown]
# ---
